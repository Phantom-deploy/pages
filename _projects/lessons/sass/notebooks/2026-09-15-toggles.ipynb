# %% [raw]
# ---
# layout: post
# title: SASS Toggles
# categories: [SASS, Toggles]
# lesson_language: SASS
# lesson_topic: Toggles
# lesson_source: OCS
# lesson_type: lesson
# assignment: true
# assignment_submission_type: link
# assignment_creator_uids:
#     - "jm1021"
#     - "fred"
# microblog: true
# author: Salma, Isha, Aashi, Emily
# permalink: /sass/toggles
# ---

# %% [markdown]
# ## Switches (Refactor Toggles for open-coding)
#
#
# ### What Are Toggles?
# Toggles are a kind of switch. You use them to turn things on and off, or check criteria.
#
# You probably use toggles every day without even realizing it! Toggles are used in apps, websites, and devices to quickly turn settings on or off.
#
# ### Lesson Plan
# By the end of this lesson, students should know
# - What a toggle is
# - How they work
# - How to impliment one into their code
# - Proper uses for toggles
#
# **Objective**: Learn the SASS shortcut for implimenting a toggle into HTML
#
# ### How do Toggles Fit in College-Ready Standards?
#
# Learning how to create toggles builds skills that are useful for college-level computer science and programming. Toggles demonstrate selection because the interface changes based on whether a condition is true or false, such as whether a checkbox is checked. This connects to College Board's CSP concepts of selection, user interaction, and responsive program design.
#
# **Reference Table**
#
# | Toggle Part | Semantic Tag | OCS SASS Utility Classes | Purpose / Example |
# | :--- | :--- | :--- | :--- |
# | **Toggle Container** | `<label>` | `ocs__toggle` | Holds the toggle input, track, and label together |
# | **Toggle Input** | `<input type="checkbox">` | `ocs__toggle-input` | Controls whether the toggle is on or off |
# | **Toggle Track** | `<span>` | `ocs__toggle-track` | Creates the visible switch that changes appearance when toggled |
# | **Toggle Label** | `<span>` | `ocs__toggle-label` | Displays text describing what the toggle controls |
# | **Green Toggle** | `<label>` | `ocs__toggle ocs__toggle--green` | Creates a toggle with the green checked-state style |
# | **Checked State** | `<input>` | `:checked` | Detects when the toggle is turned on and changes its appearance |
# | **Toggle Status** | `<output>` | `aria-live="polite"` | Displays the current toggle status and updates when the toggle changes |
#
#
# ---
#
# ### What Are Toggles Good For?
#
# Toggles let users quickly turn a setting on or off. They are commonly used in apps and websites for things like:
#
# - Notifications
# - Dark Mode
# - Privacy settings
# - Battery settings
# - Website features
#
# Toggles work best when there are two choices, such as on/off or enabled/disabled.
#
# In the UI Runner below, this idea is implemented using the `:checked` selector.
#
# ---
#
# ## Shortcut
#
# This is the code for a basic toggle and what you'd write in your code.
#
# ```html
# <label class="ocs__toggle ocs__toggle--green">
#   <input id="feature-toggle" class="ocs__toggle-input" type="checkbox" checked>
#   <span class="ocs__toggle-track" aria-hidden="true"></span>
#   <span class="ocs__toggle-label">My Label</span>
# </label>
# ```
# **Important**
# - Calls the "ocs__toggle" class
# -
#
# ---
# ### UI Runner

# %%
# %%html
# <!-- UI_RUNNER: Toggle example | show_code: true -->
# <!-- //Fill in the blanks! -->
#
# <style>
# .switch {
#     position: relative;
#     display: flex;
#     width: 54px;
#     height: 31px;
# }
#
# .switch input[type="checkbox"] {
#     opacity: 0;
#     width: 0;
#     height: 0;
# }
#
# .slider {
#     position: absolute;
#     inset: 0;
#     border: 1px solid var(--ui-border, #666);
#     border-radius: 100px;
#     background: var(--panel-mid, gray);
#     cursor: pointer;
# }
#
# .slider:before {
#     content: "";
#     position: absolute;
#     width: 23px;
#     height: 23px;
#     top: 3px;
#     left: 4px;
#     bottom: 0;
#     border-radius: 50%;
#     background: var(--pref-text-color, white);
#     transition: transform 0.2s;
# }
#
# input[type="checkbox"]:checked + .slider {
#     background: var(--pref-accent-color, blue);
# }
#
# input[type="checkbox"]:checked + .slider:before {
#     transform: translateX(22px);
#     outline: 2px solid var(--pref-accent-color, blue);
# }
# </style>
#
# <h3>Checkbox</h3>
# <label>
#   <input type="checkbox">
# </label>
#
# <h3>Slider</h3>
# <label class="switch">
#   <input type="checkbox">
#   <span class="slider" aria-hidden="true"></span>
#   <span>Toggle</span>
# </label>

# %% [markdown]
# ### Code Breakdown
#
# 1. Set Up the `.switch`
#    - Set the toggle's position, size, padding, and alignment.
#
# 2. Set Up the Checkbox
#    - Select the checkbox and make it invisible while keeping it functional.
#
# 3. Style the `.slider`
#    - Create the visible toggle with its position, rounded shape, background color, and transition.
#
# 4. Create the Slider Button
#    - Use `&:before` to create the white circle and set its size, position, and shadow.
#
# 5. Add the Checked State
#    - Use `&:checked + .slider` to change the toggle's color when it is turned on.
#    - The `.green` class can change the checked color to `$green1`.
#
# 6. Move the Slider Button
#    - Use `translateX(27px)` to move the white circle when the toggle is turned on.
#
# 7. Add Focus and Transitions
#    - Add a focus shadow with `&:focus + .slider`.
#    - Use `transition` to make the toggle changes smooth.
#
#
# ---

# %%
# %%html
# <!-- UI_RUNNER: Toggle example | show_code: true -->
# <!-- //Fill in the blanks! -->
#
# <div>
#   <label class="ocs__toggle ocs__toggle--green">
#     <input id="toggle1" class="ocs__toggle-input" type="checkbox">
#     <span class="ocs__toggle-track" aria-hidden="true"></span>
#     <span class="ocs__toggle-label">Do you have family members who have or have had cancer?</span>
#   </label>
#
#   <label class="ocs__toggle ocs__toggle--green">
#     <input id="toggle2" class="ocs__toggle-input" type="checkbox">
#     <span class="ocs__toggle-track" aria-hidden="true"></span>
#     <span class="ocs__toggle-label">Do you consume alcohol or use tobacco?</span>
#   </label>
#
#   <label class="ocs__toggle ocs__toggle--green">
#     <input id="toggle3" class="ocs__toggle-input" type="checkbox">
#     <span class="ocs__toggle-track" aria-hidden="true"></span>
#     <span class="ocs__toggle-label">Do you forget to wear sunscreen?</span>
#   </label>
#
#   <label class="ocs__toggle ocs__toggle--green">
#     <input id="toggle4" class="ocs__toggle-input" type="checkbox">
#     <span class="ocs__toggle-track" aria-hidden="true"></span>
#     <span class="ocs__toggle-label">Do you consume less than 48 oz of water and 30 grams of fiber a day?</span>
#   </label>
#
#   <br>
#
#   <button id="checkRisk">Check Risk</button>
#
#   <p id="riskOutput"></p>
# </div>
#
# <script>
#   document.getElementById("checkRisk").addEventListener("click", function() {
#
#     // Reset the risk to 0 every time the button is clicked
#     let risk = 0;
#
#     const toggles = document.querySelectorAll(".ocs__toggle-input");
#
#     toggles.forEach(function(toggle) {
#       if (toggle.checked) {
#         risk += 25;
#       }
#     });
#
#     // If no toggles are checked, risk stays at 0%
#     document.getElementById("riskOutput").textContent =
#       "Current Cancer Exposure Risk: " + risk + "%";
#   });
# </script>

# %% [markdown]
# ## Popcorn Hack (5 min)
# Fill in the blanks!
#
# <details>
# <summary>Show answers</summary>
# Answers: checkbox, slider, alignment, border-radius, white circle
# </details>

# %% [markdown]
# Read the sentence aloud and fill in the blanks! Answers above.
#
# ```html
# <textarea id="codeEditor">;
# console.log("The ___ on a toggle keeps track of whether it is on or off.");
# console.log("The ___ is the visible part of the toggle that changes color when it is turned on");
# console.log("The .switch class controls the toggles position, size, padding, and ___.");
# console.log("The ___ Property makes the slider have rounded edges.");
# console.log("The &before class dictates the ___ of the toggle");</textarea>
#
# <button id="runButton">Run Code</button>
#
# <pre id="output"></pre>
# ```

# %% [markdown]
# ## The Beauty of SASS
#
# To use checkboxes or sliders all you need to do is use the class from SASS!  This lets you focus on logic instead of repeating style over and over.

# %%
# %%html
# <!-- UI_RUNNER: Toggle example using SASS | show_code: true -->
#
# <label class="ocs__toggle ocs__toggle--green">
#   <input id="feature-toggle" class="ocs__toggle-input" type="checkbox" checked>
#   <span class="ocs__toggle-track" aria-hidden="true"></span>
#   <span class="ocs__toggle-label">My Label</span>
# </label>
#
# Status: <output id="feature-toggle-status" aria-live="polite"></output>
#
# <script>
# {
#   const toggle = document.getElementById("feature-toggle");
#   const status = document.getElementById("feature-toggle-status");
#
#   const updateStatus = () => {
#     status.value = String(toggle.checked);
#   };
#
#   toggle.addEventListener("change", updateStatus);
#   updateStatus();
# }
# </script>

# %% [markdown]
# ## Homework
# Create your own interactive toggle (from scratch), and put it on your page!
#
# While writing this code, you will:
#
# - Create at least 3 toggles using the ocs__toggle SASS class. Make each toggle have its own label and purpose!
# - Use JavaScript to check whether each toggle is on or off and update something on your page based on the toggle's status.
# - Add a section that shows how many toggles are currently turned on. Make sure this number updates when you flip a toggle!
# - Leave comments throughout the code, either explaining something new you learned, something you had questions about, how it works, or some other comment that provides insight and proof of understanding. (2 comments minimum.)
# - Ex. “I thought .checked was interesting because it lets JavaScript tell whether the toggle is currently turned on or off!”
#
# **Rubric**
# **0.88**
# Completed all homework requirements stated above
#
# **.92 - Above and beyond!**
# - Left extra (insightful) comments throughout the code of any kind.
# - Connects the toggle to a feature! This shows the highest form of mastery.
#     - In other words, your toggle actually toggles something. flipping the slider triggers a feature of some kind.
#
# Make sure to submit the link to your homework in the microblog on the top right!

# %% [markdown]
# <br>
#
# <label class="ocs__toggle ocs__toggle--green">
#   <input id="feature-toggle" class="ocs__toggle-input" type="checkbox" checked>
#   <span class="ocs__toggle-track" aria-hidden="true"></span>
#   <span class="ocs__toggle-label">My Label</span>
# </label>
#
# Status: <output id="feature-toggle-status" aria-live="polite"></output>
#
# <script>
# {
#   const toggle = document.getElementById("feature-toggle");
#   const status = document.getElementById("feature-toggle-status");
#
#   const updateStatus = () => {
#     status.value = String(toggle.checked);
#   };
#
#   toggle.addEventListener("change", updateStatus);
#   updateStatus();
# }
# </script>
