# %% [raw]
# ---
# layout: post
# categories: [Python, Iterations]
# lesson_language: Python
# lesson_topic: Iterations
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# microblog: true
# toc: false
# comments: false
# title: 3.08 Iterations
# description: Learn Python iteration with hands-on loop examples, control flow, and code runner challenges.
# permalink: /python/iterations
# ---

# %% [markdown]
# # 3.08 Iterations
#
# Iteration means repeating a set of steps. In Python, loops help programs process lists, keep checking a condition, skip values that do not matter, and stop when the important case has been found.
#
# This lesson uses short CodeRunner examples so you can run each loop, read the output, and connect the result back to the control flow.

# %% [markdown]
# ## The Big Idea
#
# Loops let a program repeat work without copying the same instructions over and over.
#
# You will practice four core ideas:
#
# - `for` loops repeat through a known sequence, such as a list of readings.
# - `while` loops repeat until a condition changes.
# - `continue` skips the current item and keeps checking the rest.
# - `break` stops a loop early when the program has found what it needs.

# %% [markdown]
# ## Scenario
#
# The examples use a simple emergency-response theme. A program checks sensor readings, cooling temperatures, and fire-zone alerts.
#
# Run each example, then explain which loop decision caused each line of output.

# %%
# CODE_RUNNER: Popcorn Hack 1 - Fix the for loop, count alerts, and print a summary.
# Goal: inspect every reading, count high alerts, and report the highest reading.
readings = [34, 42, 31, 48, 29, 37]
alert_cutoff = ____
high_alerts = ____
highest_reading = readings[0]

# TODO: Replace the blank with the list variable.
for reading in ____:
    print(f"Checking reading: {reading}")

    # TODO: Update highest_reading when this reading is bigger.
    if reading > ____:
        highest_reading = ____

    # TODO: Check against alert_cutoff and count high alerts.
    if reading >= ____:
        high_alerts ____ 1
        print("High alert: investigate this reading.")
    else:
        print("Reading is within the normal range.")

print(f"High alerts found: {high_alerts}")
print(f"Highest reading: {highest_reading}")

# %% [markdown]
# ## `for` Loops: Inspect Each Item
#
# A `for` loop is best when you already have a collection to examine. The loop runs once for each item, using the same logic every time.
#
# In the runner above, `reading` should change on every pass through the loop. One block of code can inspect many values.
#
# **5-minute check:** your finished code should inspect all 6 readings, count only readings `40` or higher, and print the highest value.

# %%
# CODE_RUNNER: Popcorn Hack 2 - Fix the while loop and add a safety stop.
# Goal: cool until the temperature is safe, but stop if too many cycles happen.
temperature = 85
safe_temperature = ____
cooling_step = ____
max_cycles = ____
cooldown_count = 0

# TODO: Keep looping while the temperature is unsafe.
while temperature > ____:
    # TODO: Decrease temperature by cooling_step each loop.
    temperature ____ ____
    cooldown_count += 1
    print(f"Cooling down... temperature is now {temperature}.")

    # TODO: If cooldown_count reaches max_cycles, print a warning and stop the loop.
    if cooldown_count ____ max_cycles:
        print("Safety stop: cooling took too many cycles.")
        ____

print(f"Stabilized after {cooldown_count} cooling cycles.")

# %% [markdown]
# ## `while` Loops: Repeat Until Safe
#
# A `while` loop keeps running as long as its condition is true. This is useful when you do not know exactly how many repetitions will be needed.
#
# The important rule: make sure something inside the loop eventually changes the condition. Otherwise, the loop can run forever.
#
# **5-minute check:** your finished code should use a safe temperature of `30`, cool by `15`, and include a `break` safety stop after `6` cycles.

# %%
# CODE_RUNNER: Popcorn Hack 3 - Add continue, break, and response counters.
# Goal: skip safe zones, count crew responses, and stop at the first severe fire.
fire_levels = [7, 4, 2, 9, 1]
safe_cutoff = ____
severe_cutoff = ____
responses = 0
severe_found = False

for level in fire_levels:
    if level <= ____:
        print(f"Zone is stable: {level}")
        # TODO: Skip the rest of this loop pass.
        ____

    # TODO: Count this crew response.
    responses ____ 1
    print(f"Crew responds to level {level}")

    if level >= ____:
        print("Severe fire detected - focus on the main fire line.")
        severe_found = ____
        # TODO: Stop the loop after the severe fire is found.
        ____

print(f"Crew responses sent: {responses}")
print(f"Severe fire found: {severe_found}")

# %% [markdown]
# ## `break` and `continue`
#
# Loop-control statements help a program make better decisions while it repeats.
#
# - `continue` skips the rest of the current loop pass and moves to the next item.
# - `break` exits the loop completely.
#
# In the runner above, safe zones should be skipped, while a severe fire should stop the scan and become the top priority.
#
# **5-minute check:** your finished code should skip levels `2` or below, stop at level `8` or higher, and print whether a severe fire was found.

# %% [markdown]
# ## Quick Challenge
#
# Before you run the next example, predict the output.
#
# A fire crew checks several alert readings. If a reading is `3` or higher, the zone is still active. If it is below `3`, the zone is stable.
#
# Use the loop below to count how many fire zones are still active.
#
# **5-minute check:** your finished code should count active zones, stable zones, the total alert score, and print `high` or `monitor` for urgency.

# %%
# CODE_RUNNER: Popcorn Hack 4 - Finish the counter, filter safe zones, and calculate urgency.
# Goal: count active zones, count stable zones, and label the final urgency level.
alerts = [3, 2, 5, 1, 8, 4, 0]
active_zones = 0
stable_zones = 0
total_alert_score = 0

for alert in alerts:
    # TODO: Add every alert to total_alert_score.
    total_alert_score ____ alert

    # TODO: Check whether the alert is active.
    if alert ____ 3:
        # TODO: Count this active zone.
        active_zones ____ 1
        print(f"Alert at {alert}: fire still active")
    else:
        # TODO: Count this stable zone.
        stable_zones ____ 1
        print(f"Alert at {alert}: zone is stable")

# TODO: Set urgency to "high" if active_zones is 4 or more; otherwise use "monitor".
if active_zones ____ 4:
    urgency = ____
else:
    urgency = ____

print(f"Total active fire zones: {active_zones}")
print(f"Total stable zones: {stable_zones}")
print(f"Total alert score: {total_alert_score}")
print(f"Urgency level: {urgency}")

# %% [markdown]
# ## Lesson Flow
#
# | Time | Activity | Purpose |
# | --- | --- | --- |
# | 0-3 min | Introduce iteration and the scenario | Connect loops to repeated decisions |
# | 3-10 min | Run the `for` loop popcorn hack | See how a loop visits every item |
# | 10-17 min | Run the `while` loop popcorn hack | See how a condition controls repetition |
# | 17-25 min | Fix `break` and `continue` | Trace skipped and stopped loop passes |
# | 25-35 min | Complete the quick challenge | Count matching items with a loop |
# | 35-45 min | Discuss practice tasks | Prepare for the 10-minute homework mini-program |

# %% [markdown]
# ## Learning Targets
#
# By the end of this lesson, you should be able to:
#
# - Explain why iteration reduces repeated code.
# - Choose a `for` loop when processing a known collection.
# - Choose a `while` loop when repetition depends on a changing condition.
# - Trace how `break` and `continue` change loop behavior.
# - Write a loop that counts, filters, or stops based on data.

# %% [markdown]
# ## Practice Tasks
#
# ### Practice 1: Predict the Output
#
# For each value in `[2, 4, 6, 8]`, predict what prints if the program prints `value * 2`.
#
# ### Practice 2: Explain the Loop
#
# A loop checks each number from `0` to `10`, skips odd numbers with `continue`, and prints the remaining values. Explain how `continue` changes the flow.
#
# ### Practice 3: Choose the Right Loop
#
# Choose `for` or `while` for each task and explain your choice.
#
# 1. Print the numbers 1 through 20.
# 2. Keep asking for a password until the correct one is entered.
# 3. Read every item in a list of quiz scores and compute the total.
#
# ### Practice 4: Trace `break` and `continue`
#
# Trace the list `[10, 15, 7, 20, 5, 25]`. Skip scores below `10`, print valid scores, and stop when a score is at least `20`.
#
# Explain what happens when the code reaches `7`, `20`, and `25`.

# %% [markdown]
# ## Grading Checklist
#
# | Requirement | Points | What earns credit |
# | --- | ---: | --- |
# | Popcorn hacks | 0.3 | Completes the missing loop variables, conditions, counters, and stop logic. |
# | Trace explanation | 0.2 | Explains what `continue` skips and what `break` stops. |
# | Homework data setup | 0.2 | Uses at least 8 values, clear thresholds, and meaningful variable names. |
# | Homework loop logic | 0.2 | Includes filtering, counting, a running total, and an early stop. |
# | Homework summary | 0.1 | Prints a clear final report with labels. |
# | **Total** | **1.0** | |

# %% [markdown]
# ## Submission and Homework
#
# ### Homework: Build a Loop-Based Checker (10 minutes)
#
# Build a new Python program in your own notebook. It should feel like a small monitoring tool, not just one copied loop.
#
# Your program must:
#
# 1. Use a list of at least 8 values.
# 2. Define at least 2 threshold variables, such as `safe_cutoff` and `critical_cutoff`.
# 3. Use a `for` loop to check every value.
# 4. Use `continue` to skip values that do not need action.
# 5. Use `break` once a critical value is found.
# 6. Track at least 3 summary values, such as `checked_count`, `action_count`, and `total_score`.
# 7. Print a labeled message inside the loop for each value that is checked.
# 8. Print a final summary with all tracked values and whether a critical value was found.
#
# Starter idea you may adapt:
#
# - Check air-quality readings, server loads, wildfire alerts, quiz scores, or battery levels.
# - Skip safe values.
# - Count values that need action.
# - Stop when a critical value appears.
# - Print a final report that someone could understand without reading your code.
#
# ### Submission Safety Rules
#
# > [!IMPORTANT]
# > Make sure every submitted code cell runs without errors. Keep the `# CODE_RUNNER:` comment at the top of each CodeRunner cell so the page can render the interactive runner correctly.
#
# ### Submit Your Homework
#
# Once your notebook is committed and pushed, submit your portfolio link using the form below.
#
# <a class="ocs__btn accent fill" href="https://docs.google.com/forms/d/e/1FAIpQLSe_t4QR6x8yoQ_f4DH1b-InlJGoUo8G3oitclAtqxlpbmPeqw/viewform?usp=publish-editor" target="_blank" rel="noopener">Submit Homework</a>

# %% [markdown]
# ## Final Check
#
# Before you submit, make sure you can answer these questions:
#
# - What condition controls each loop?
# - Which variable changes during the loop?
# - When does the loop skip an item?
# - When does the loop stop early?
# - What final result does the loop calculate?
